# %% [markdown]
# # Convex Optimization
#
# - Notebook Link: https://tinyurl.com/cw23-co-notebook

# %%
# !pip install cvxpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cvxpy in /usr/local/lib/python3.10/dist-packages (1.3.1)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy) (3.2.3)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from cvxpy) (1.22.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from cvxpy) (1.10.1)
# Requirement already satisfied: setuptools>65.5.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy) (67.7.2)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy) (0.1.7)

# %% [markdown]
# CVXPY is a Python-embedded modeling language for ***convex optimization*** problems. It automatically transforms the problem into ***standard form***, calls a solver, and unpacks the results.
#
# - What is ***optimisation***?
#   ***Optimisation*** is central to decision making tasks in various fields. The task of decision masking involves choices between various alternatives. These choices are governed by our desire to make the "best" decision. The measure of goodness of the alternatives is described by an objective
# function or performance index. Optimization theory and methods deal with selecting
# the best alternative in the sense of the given objective function
#
# - Example:
#
#   ***CP says hi!!!***
#
#   A Knapsack Problem?
#   - You have limited strength, so there is a maximum weight knapsack you can carry
#   - Each object has a particular weight and a value and hence anyone would like to maximise the value for the maximum weight that one can carry
#   - This maximisation of an objective i.e the value of the objects picked under a variety of cosntraints i.e the total weight that you can carry is an example of an optimisation problem
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - What is Convex Optimisation?
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# - What is the standard form?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Simple Variable Example
#
# - `cp.Variable(n)` defines a vector of variables or dimensions on whose value the objective function is dependent on. Often constraints are placed on these variables. `n` indicates the number of Variables.
#
# - `constraints` is a list of constraints that the variables need to follow and the optimisation must obey these constraints and find the optimum under these constraints.
#
# - `cp.Problem()` creates a problem instance that needs to be solved by calling the

# %%
import cvxpy as cp

# Create two scalar optimization variables.
x = cp.Variable()
y = cp.Variable()

# Create two constraints.
constraints = [x + y == 2,
               x - y >= 2]

# Form objective.
obj = cp.Minimize((x - y)**2)

# Form and solve problem.
prob = cp.Problem(obj, constraints)
prob.solve()  # Returns the optimal value.
print("status:", prob.status)
print("optimal value", prob.value)
print("optimal var", x.value, y.value)
# Out:
# status: optimal
# optimal value 4.0
# optimal var 2.0 3.140172426481966e-22

# %%
import cvxpy as cp
import numpy as np

# Problem data.
m = 30
n = 20
np.random.seed(1)
A = np.random.randn(m, n)
b = np.random.randn(m)

# Construct the problem.
x = cp.Variable(n)
objective = cp.Minimize(cp.sum_squares(A @ x - b))
constraints = [0 <= x, x <= 1]
prob = cp.Problem(objective, constraints)

# The optimal objective value is returned by `prob.solve()`.
result = prob.solve()

# The optimal value for x is stored in `x.value`.
print(x.value)
# The optimal Lagrange multiplier for a constraint is stored in
# `constraint.dual_value`.
print(constraints[0].dual_value)
# Out:
# [-1.79109253e-19  2.85112420e-02  2.79973443e-19  3.37658751e-20
#  -2.72802659e-19  1.49285011e-01 -9.97212062e-20  8.35373892e-20
#   2.46718649e-01  5.78224144e-01 -4.03739462e-19  1.01242860e-03
#  -9.28486200e-20  2.26767464e-01 -1.58813677e-19 -8.97232308e-20
#  -1.22145726e-19 -1.51509432e-19  1.12060673e-19 -3.48318630e-19]
# [ 2.50938945  0.          2.78354615  1.79425782 13.08579183  0.
#   0.73716363  3.35344995  0.          0.          8.93825054  0.
#   7.02955161  0.          4.71068649  3.18873635  2.06090107 10.08166738
#   3.0481157   8.53268239]

# %% [markdown]
# Get a grip over the framework by trying it on a simple function that you can think off. If possible graph the function and prove your point. Make sure that the function is convex or if other optimisation look up for appropriate solvers.

# %%
x = cp.Variable()
y = (x**3 - 3*(x**2))
y.is_quasiconvex()
# Out:
# False

# %%
import cvxpy
import numpy as np

# The data for the Knapsack problem
# P is total weight capacity of sack
# weights and utilities are also specified
P = 165
weights = np.array([23, 31, 29, 44, 53, 38, 63, 85, 89, 82])
utilities = np.array([92, 57, 49, 68, 60, 43, 67, 84, 87, 72])

# The variable we are solving for
selection = cvxpy.Variable(len(weights),boolean=True)

# The sum of the weights should be less than or equal to P
weight_constraint = weights * selection <= P

# Our total utility is the sum of the item utilities
total_utility = utilities * selection

# We tell cvxpy that we want to maximize total utility 
# subject to weight_constraint. All constraints in 
# cvxpy must be passed as a list
knapsack_problem = cvxpy.Problem(cvxpy.Maximize(total_utility), [weight_constraint])

# Solving the problem
knapsack_problem.solve(solver=cvxpy.GLPK_MI)
# Out:
# /home/kyrylo/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:612: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 5 times so far.
#
#   warnings.warn(msg, UserWarning)
# /home/kyrylo/.local/lib/python3.8/site-packages/cvxpy/expressions/expression.py:612: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
# This code path has been hit 6 times so far.
#
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# Input In [13], in <cell line: 26>()
#      23 knapsack_problem = cvxpy.Problem(cvxpy.Maximize(total_utility), [weight_constraint])
#      25 # Solving the problem
# ---> 26 knapsack_problem.solve(solver=cvxpy.GLPK_MI)
#
# File ~/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py:493, in Problem.solve(self, *args, **kwargs)
#     491 else:
#     492     solve_func = Problem._solve
# --> 493 return solve_func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py:1054, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1051         self.unpack(chain.retrieve(soln))
#    1052         return self.value
# -> 1054 data, solving_chain, inverse_data = self.get_problem_data(
#    1055     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1056 )
#    1058 if verbose:
#    1059     print(_NUM_SOLVER_STR)
#
# File ~/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py:631, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     629 if key != self._cache.key:
#     630     self._cache.invalidate()
# --> 631     solving_chain = self._construct_chain(
#     632         solver=solver, gp=gp,
#     633         enforce_dpp=enforce_dpp,
#     634         ignore_dpp=ignore_dpp,
#     635         canon_backend=canon_backend,
#     636         solver_opts=solver_opts)
#     637     self._cache.key = key
#     638     self._cache.solving_chain = solving_chain
#
# File ~/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py:881, in Problem._construct_chain(self, solver, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts)
#     839 def _construct_chain(
#     840         self,
#     841         solver: Optional[str] = None,
#    (...)
#     846         solver_opts: Optional[dict] = None
#     847 ) -> SolvingChain:
#     848     """
#     849     Construct the chains required to reformulate and solve the problem.
#     850
#    (...)
#     879     A solving chain
#     880     """
# --> 881     candidate_solvers = self._find_candidate_solvers(solver=solver, gp=gp)
#     882     self._sort_candidate_solvers(candidate_solvers)
#     883     return construct_solving_chain(self, candidate_solvers, gp=gp,
#     884                                    enforce_dpp=enforce_dpp,
#     885                                    ignore_dpp=ignore_dpp,
#     886                                    canon_backend=canon_backend,
#     887                                    solver_opts=solver_opts)
#
# File ~/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py:744, in Problem._find_candidate_solvers(self, solver, gp)
#     742 if solver is not None:
#     743     if solver not in slv_def.INSTALLED_SOLVERS:
# --> 744         raise error.SolverError("The solver %s is not installed." % solver)
#     745     if solver in slv_def.CONIC_SOLVERS:
#     746         candidates['conic_solvers'] += [solver]
#
# SolverError: The solver GLPK_MI is not installed.

# %% [markdown]
# Try DP based solution for different lengths and verify if CVXPY converges to the solution for different lengths of N. (Exercise)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [0]*40 + [i/10 for i in range(0,40)] + [4]*40 + [i/10 for i in range(40,0,-1)] + [0]*40
x = np.array(x)
x = (x**3) 
x = x + np.random.uniform(-2,2,x.shape[0])
# np.save("input.npy",x)
plt.plot(range(x.shape[0]),x)

# %%
obj = cp.Minimize(1/2*cp.sum((x-r)**2) + 100*cp.sum(cp.abs(r[1:] - r[:-1]) ) + 
                 + 50*cp.sum(cp.abs(r[3:] - 3*r[2:-1]+3*r[1:-2] - r[:-3] )))

# %%
r = cp.Variable(x.shape)
print(r[:-1].shape)
diff = ((r[1:]-r[:-1]))
print(diff.shape)
obj = cp.Minimize(1/2*cp.sum((x-r)**2) + 100*cp.sum(cp.abs(r[1:] - r[:-1]) ) + 
                 + 50*cp.sum(cp.abs(r[3:] - 3*r[2:-1]+3*r[1:-2] - r[:-3] )))
# 1/2*cp.sum((x-r)**2) + 100*cp.sum(cp.abs(r[1:] - r[:-1]))
prob = cp.Problem(obj, [])
prob.solve()
# print(r.value)
plt.plot(range(x.shape[0]), r.value)
# Out:
# (199,)
# (199,)

# %% [markdown]
# ## Cinematic Shot Generation using Convex Optimizaiton
#
# **Data**: https://tinyurl.com/cw23-co-data

# %%
# This package is preferred over simple opencv package 
# !pip install opencv-contrib-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-contrib-python in /home/kyrylo/.local/lib/python3.8/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in /home/kyrylo/.local/lib/python3.8/site-packages (from opencv-contrib-python) (1.24.1)
#
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

# %%
# %%capture
source_folder = 'inputs'

# !mkdir -p ./{source_folder} > /dev/null ;

# %%
video = 'dance2.mp4'
# bbox = "dance2-p1-MS.txt"
bbox = "noisy_p1_ms.npy"

source_path = f'./{source_folder}/{video}'

# %%
# %%capture
output_folder = 'outputs'

# !mkdir -p ./{output_folder} > /dev/null ;

# %% [markdown]
# ### Extracting Frames from Video

# %%
data_folder = 'frames'
frames_path = f"./{data_folder}/{video.rsplit('.', 1)[0]}"

# %%
# %%capture

# !mkdir -p {frames_path}

# %%
# !ffmpeg -i inputs/dance2.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'inputs/dance2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.14.100
#   Duration: 00:01:20.02, start: 0.000000, bitrate: 2119 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2560x1350 [SAR 1:1 DAR 256:135], 1985 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# At least one output file must be specified

# %%
## Use ffmpeg to extract frames for first 10-30 seconds of the video (see documentation: https://ffmpeg.org/ffmpeg.html)

# !ffmpeg -i inputs/dance2.mp4 -vf fps=24 -ss 00:00:0.0 -t 80 ./frames/dance2/out%d.png
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'inputs/dance2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.14.100
#   Duration: 00:01:20.02, start: 0.000000, bitrate: 2119 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2560x1350 [SAR 1:1 DAR 256:135], 1985 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to './frames/dance2/out%d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: png, rgb24, 2560x1350 [SAR 1:1 DAR 256:135], q=2-31, 200 kb/s, 24 fps, 24 tbn, 24 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 png
# frame= 1920 fps= 58 q=-0.0 Lsize=N/A time=00:01:20.00 bitrate=N/A speed=2.41x
# video:4799382kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %% [markdown]
# ### Loading Bounding Boxes

# %%
## Load .npy file
box = np.load('./inputs/noisy_p1_ms.npy')
print(box)
# Out:
# [[ 46.64756873 624.17780576  33.20999622]
#  [ 34.17800017 623.1790185   19.3995514 ]
#  [ 42.89799486 636.35844697  33.7826512 ]
#  ...
#  [898.28495439 740.4725556  153.64610037]
#  [895.91689089 748.73986934 166.17318589]
#  [903.67272915 758.23822426 163.76467496]]

# %% [markdown]
# ### Saving/Visualizing Video with Noisy BBox Coordinates

# %%
def plot_bbox(bbox, n=100):
    fig = plt.figure(num=None, figsize=(20, 5), dpi=100)
    axes = fig.subplots(1, 3)

    axes[0].plot(range(n), bbox[:n,0])
    axes[1].plot(range(n), bbox[:n,1])
    axes[2].plot(range(n), bbox[:n,2])

    plt.show()
    plt.close(fig)

# %%
plot_bbox(box, n=200)

# %%
# Write a function to Draw BBox in frames and save as video
loc = './frames/dance2/'
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image


def save_frames(loc, box, file_name):
    for x in range(1920):
        img = cv2.imread(loc+f'out{x+1}.png')
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        locb = box[x].astype(int)
        # print(type(locb[0]))
        print(locb[0]-locb[2],locb[1]-locb[2])
        cv2.rectangle(img, (locb[0]-locb[2],locb[1]-locb[2]),
                           (locb[0]+locb[2],locb[1]+locb[2]),(0,0,255), 2)
        cv2.imwrite(loc+f'outx{x+1}.png',img)
    
#         plt.imshow(img)

# %%
save_frames(loc, box, file_name=f'dance2_noisy')
# Out:
# 13 591
# 15 604
# 9 603
# -20 610
# 34 590
# 38 596
# 57 597
# -8 607
# -12 594
# 15 596
# 74 623
# -2 588
# -11 612
# 45 609
# 36 603
# 65 606
# -22 613
# -8 596
# 44 593
# 35 605
# 24 609
# 70 599
# -6 597
# 38 595
# 53 585
# 26 580
# 0 586
# 91 584
# 84 581
# 37 565
# 84 559
# 32 544
# 24 546
# 102 542
# 99 537
# 81 551
# 69 521
# 70 543
# 135 519
# 121 518
# 108 511
# 138 517
# 86 518
# 99 496
# 156 517
# 86 511
# 79 506
# 153 501
# 97 493
# 160 498
# 147 509
# 179 510
# 130 493
# 127 496
# 137 491
# 140 501
# 160 514
# 151 496
# 179 499
# 237 486
# 204 502
# 269 498
# 237 487
# 251 504
# 289 518
# 288 508
# 344 522
# 341 523
# 359 500
# 318 526
# 346 512
# 339 508
# 421 517
# 385 513
# 424 530
# 436 514
# 475 536
# 442 520
# 464 537
# 481 542
# 496 529
# 588 544
# 598 541
# 566 539
# 627 540
# 607 537
# 638 535
# 600 526
# 644 527
# 625 523
# 649 528
# 583 550
# 561 543
# 638 536
# 546 524
# 626 539
# 577 549
# 513 528
# 587 545
# 589 540
# 512 545
# 525 534
# 496 540
# 524 530
# 467 534
# 483 530
# 541 544
# 535 523
# 534 533
# 493 532
# 556 542
# 518 535
# 585 535
# 513 528
# 548 536
# 548 537
# 608 528
# 613 537
# 576 526
# 636 519
# 584 547
# 589 523
# 649 537
# 613 535
# 632 527
# 658 535
# 663 529
# 726 545
# 723 521
# 677 532
# 718 535
# 696 545
# 715 528
# 777 543
# 751 531
# 702 530
# 779 549
# 774 542
# 803 544
# 768 547
# 739 542
# 753 537
# 754 542
# 808 550
# 767 551
# 816 565
# 829 552
# 866 571
# 839 548
# 823 559
# 870 569
# 886 580
# 874 588
# 822 575
# 895 579
# 848 588
# 892 582
# 896 585
# 898 591
# 916 586
# 863 599
# 881 581
# 831 579
# 859 588
# 850 589
# 880 592
# 897 591
# 916 577
# 880 571
# 907 568
# 899 561
# 888 578
# 922 585
# 927 566
# 882 572
# 916 557
# 844 574
# 920 575
# 888 576
# 910 574
# 884 575
# 875 567
# 938 556
# 854 583
# 873 573
# 902 566
# 960 586
# 880 561
# 890 576
# 883 574
# 879 552
# 934 572
# 899 564
# 959 559
# 879 570
# 910 554
# 877 561
# 959 563
# 912 565
# 920 539
# 893 553
# 948 549
# 916 533
# 894 544
# 889 533
# 901 525
# 896 528
# 920 522
# 926 529
# 927 518
# 887 536
# 897 518
# 841 522
# 859 508
# 833 517
# 896 518
# 807 513
# 883 517
# 884 505
# 877 510
# 890 519
# 842 520
# 809 516
# 854 528
# 825 520
# 796 498
# 867 525
# 822 525
# 897 515
# 807 516
# 837 518
# 864 524
# 818 526
# 816 501
# 797 513
# 810 503
# 836 518
# 845 506
# 858 512
# 883 505

# %%
# !ffmpeg -framerate 24 -i ./frames/dance2/outx%d.png output.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from './frames/dance2/outx%d.png':
#   Duration: 00:00:10.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 2560x1350, 24 tbr, 24 tbn, 24 tbc
# File 'output.mp4' already exists. Overwrite ? [y/N] ^C

# %% [markdown]
# ### Smoothing out the tracks by posing this as an Optimization Problem

# %%
def f(x,r):
    return 1/2*cp.sum((x-r)**2) + 100*cp.sum(cp.abs(r[1:] - r[:-1]) ) +  50*cp.sum(cp.abs(r[3:] - 3*r[2:-1]+3*r[1:-2] - r[:-3] ))
    
x,y,z = box[:,0],box[:,1], box[:,2]
p = cp.Variable(x.shape)
q = cp.Variable(x.shape)
r = cp.Variable(x.shape)
# print(r.shape)
diff = ((r[1:]-r[:-1]))
obj = cp.Minimize(f(x,p)+f(y,q)+f(z,r))
# 1/2*cp.sum((x-r)**2) + 100*cp.sum(cp.abs(r[1:] - r[:-1]))
prob = cp.Problem(obj, [])
prob.solve()
# print(r.value)
# _, axs = plt.subplots()
box_smooth = np.array([p.value,q.value,r.value])
box_smooth = box_smooth.T
print(box_smooth.shape)
print(p)
# Out:
# (1920, 3)
# var12274

# %% [markdown]
# ### Saving/Visualizing Resultant Output

# %%
print(np.shape(box_smooth))
plot_bbox(box_smooth, n=200)
# Out:
# (1920, 3)

# %%
save_frames(loc, box_smooth, file_name=f'dance2_smooth')
# Out:
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 20 602
# 21 602
# 22 601
# 25 601
# 27 599
# 29 597
# 32 595
# 34 592
# 37 589
# 41 586
# 44 582
# 49 578
# 52 573
# 56 568
# 59 562
# 63 557
# 68 552
# 72 546
# 77 541
# 83 536
# 90 533
# 96 528
# 102 524
# 108 521
# 110 517
# 112 515
# 111 512
# 111 510
# 113 508
# 115 506
# 120 505
# 125 503
# 131 502
# 136 501
# 139 500
# 141 500
# 141 499
# 139 498
# 142 498
# 148 499
# 157 499
# 169 499
# 186 500
# 205 501
# 222 501
# 239 502
# 256 503
# 271 505
# 286 506
# 300 508
# 314 509
# 326 511
# 338 513
# 349 514
# 361 516
# 373 518
# 386 519
# 399 521
# 413 523
# 427 525
# 442 527
# 458 529
# 476 530
# 498 532
# 522 533
# 550 534
# 571 535
# 586 535
# 595 536
# 598 536
# 598 536
# 598 536
# 598 536
# 598 536
# 598 536
# 597 536
# 595 536
# 591 536
# 587 536
# 581 536
# 575 536
# 567 536
# 560 536
# 552 536
# 545 536
# 540 536
# 537 536
# 537 536
# 537 536
# 537 536
# 537 536
# 537 536
# 537 536
# 537 536
# 538 536
# 540 536
# 544 536
# 550 536
# 558 536
# 567 536
# 579 536
# 589 536
# 597 536
# 604 536
# 608 536
# 615 536
# 624 536
# 635 536
# 648 537
# 663 537
# 678 537
# 690 537
# 702 538
# 711 538
# 720 538
# 728 539
# 736 540
# 743 540
# 750 541
# 756 542
# 761 543
# 765 544
# 768 545
577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 725 577
# 726 577
# 728 577
# 730 577
# 733 577
# 735 577
# 737 577
# 737 577
# 737 577
# 737 577
# 737 577
# 737 577
# 737 577
# 737 577
# 737 577
# 737 577
# 737 577
# 737 577
# 737 576
# 737 576
# 737 575
# 738 574
# 740 572
# 742 570
# 744 568
# 746 566
# 747 564
# 748 561
# 748 559
# 748 556
# 748 554
# 748 552
# 748 550
# 748 547
# 748 545
# 748 543
# 748 541
# 748 540
# 748 538
# 748 536
# 748 535
# 748 533
# 749 532
# 750 531
# 753 530
# 757 529
# 759 528
# 761 528
# 762 527
# 762 527
# 762 526
# 762 526
# 762 525
# 762 525
# 762 525
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 762 524
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 523
# 761 524
# 761 524
# 762 525
# 762 526
# 763 527
# 764 528
# 764 530
# 765 531
# 765 533
# 765 535
# 765 538
# 765 540
# 765 543
# 769 546
# 775 549
# 785 551
# 794 554
# 801 556
# 807 558
# 812 560
# 815 561
# 817 562
# 817 563
# 817 563
# 817 563
# 817 563
# 817 563
# 816 563
# 810 563
# 797 563
# 778 563
# 753 563
# 727 563
# 702 563
# 676 563
# 656 563
# 641 563
# 632 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 629 563
# 633 563
# 642 563
# 655 563
# 673 563
# 691 563
# 708 563
# 725 563
# 741 563
# 757 563
# 770 563
# 780 563
# 788 563
# 794 563
# 796 563
# 796 563
# 796 563
# 796 563
# 796 563
# 796 563
# 796 563
# 798 563
# 801 563
# 806 563
# 813 563
# 822 563
# 832 563
# 842 563
# 852 563
# 861 563
# 871 563
# 880 563
# 890 563
# 900 563
# 911 563
# 922 563
# 934 563
# 945 563
# 955 563
# 965 563
# 973 563
# 980 563
# 986 563
# 991 564
# 994 564
# 995 564
# 997 564
# 998 564
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 999 565
# 995 565
# 987 565
# 974 565
# 955 565
# 931 565
# 901 565
# 875 565
# 852 565
# 833 565
# 818 565
# 805 565
# 797 565
# 790 565
# 782 565
# 775 565
# 767 566
# 759 566
# 751 567
# 745 568
# 739 570
# 735 571
# 732 573
# 731 574
# 731 576
# 731 577
# 731 578
# 731 579
# 731 580
# 731 581
# 731 582
# 731 582
# 731 583
# 731 583
# 731 583
# 731 583
# 731 583
# 731 583
# 731 583
# 732 583
# 734 583
# 737 583
# 740 583
# 744 583
# 746 583
# 749 583
# 750 583
# 752 583
# 754 583
# 758 583
# 764 583
# 771 583
# 779 583
# 785 583
# 790 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 792 583
# 791 583
# 790 583
# 789 583
# 788 583
# 786 583
# 784 583
# 781 583
# 779 583
# 777 583
# 775 582
# 774 582
# 774 581
# 774 580
# 774 579
# 774 578
# 774 577
# 774 576
# 774 575
# 774 574
# 774 574
# 774 573
# 774 573
# 774 572
# 774 572
# 773 572
# 773 572
# 772 572
# 771 572
# 770 572
# 769 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 768 572
# 767 572
# 767 572
# 767 572
# 767 572
# 767 572
# 767 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 766 572
# 765 572
# 763 572
# 760 572
# 757 572
# 754 572
# 749 572
# 744 572
# 740 572
# 736 572
# 733 572
# 730 573
# 728 573
# 726 575
# 726 576
# 726 578
# 726 579
# 726 580
# 725 581
# 724 581
# 722 582
# 719 582
# 715 582
# 711 582
# 705 582
# 701 582
# 696 582
# 692 582
# 689 582
# 686 582
# 683 582
# 681 582
# 680 582
# 679 582
# 678 582
# 678 582
# 678 582
# 678 582
# 678 582
# 679 582
# 680 582
# 681 582
# 683 582
# 685 582
# 688 582
# 691 582
# 696 582
# 703 582
# 713 582
# 726 582
# 740 582
# 757 582
# 771 582
# 782 582
# 790 582
# 796 582
# 799 582
# 803 582
# 808 582
# 814 582
# 817 582
# 819 582
# 819 582
# 819 582
# 819 582
# 819 582
# 819 582
# 820 582
# 820 582
# 822 582
# 823 582
# 824 582
# 825 582
# 825 582
# 825 582
# 825 582
# 825 582
# 825 582
# 825 582
# 825 582
# 825 582
# 824 582
# 824 582
# 823 582
# 821 582
# 816 582
# 810 582
# 802 582
# 793 582
# 781 582
# 769 582
# 756 582
# 742 582
# 730 582
# 721 582
# 715 582
# 711 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 709 582
# 711 582
# 713 582
# 716 582
# 721 582
# 726 582
# 730 582
# 732 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 582
# 733 583
# 733 583
# 733 583
# 733 583
# 733 583
# 733 583
# 733 583
# 733 583
# 733 583
# 733 583
# 733 584
# 733 584
# 733 584
# 733 584
# 732 584
# 731 584
# 731 584
# 731 584
# 731 584
# 731 584
# 731 585
# 731 585
# 731 585
# 731 585
# 731 585
# 731 585
# 731 585
# 731 585
# 731 585
# 731 585
# 731 585
# 731 585
# 732 585
# 732 585
# 733 585
# 733 585
# 733 585
# 733 585
# 733 585
# 733 585
# 733 585
# 733 585
# 732 585
# 730 585
# 727 585
# 723 585
# 720 585
# 718 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585
# 717 585

# %%
# !ffmpeg -framerate 24 -i ./frames/dance2/outx%d.png output_smooth.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from './frames/dance2/outx%d.png':
#   Duration: 00:01:20.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 2560x1350, 24 tbr, 24 tbn, 24 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5578d8295300] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5578d8295300] profile High 4:4:4 Predictive, level 5.0, 4:4:4 8-bit
# [libx264 @ 0x5578d8295300] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output_smooth.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 2560x1350, q=-1--1, 24 fps, 12288 tbn, 24 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 1920 fps= 48 q=-1.0 Lsize=   17164kB time=00:01:19.87 bitrate=1760.3kbits/s speed=1.99x
# video:17141kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.134826%
# [libx264 @ 0x5578d8295300] frame I:8     Avg QP:15.09  size:143330
# [libx264 @ 0x5578d8295300] frame P:524   Avg QP:17.23  size: 20106
# [libx264 @ 0x5578d8295300] frame B:1388  Avg QP:20.99  size:  4229
# [libx264 @ 0x5578d8295300] consecutive B-frames:  0.6%  5.8%  9.4% 84.2%
# [libx264 @ 0x5578d8295300] mb I  I16..4: 63.7%  0.0% 36.3%
# [libx264 @ 0x5578d8295300] mb P  I16..4:  4.4%  0.0%  1.4%  P16..4: 14.9%  5.5%  2.5%  0.0%  0.0%    skip:71.3%
# [libx264 @ 0x5578d8295300] mb B  I16..4:  0.2%  0.0%  0.2%  B16..8: 11.1%  0.8%  0.1%  direct: 0.2%  skip:87.4%  L0:33.8% L1:62.9% BI: 3.3%
# [libx264 @ 0x5578d8295300] coded y,u,v intra: 29.0% 17.9% 16.0% inter: 1.6% 0.8% 0.5%
# [libx264 @ 0x5578d8295300] i16 v,h,dc,p: 73% 16%  6%  5%
# [libx264 @ 0x5578d8295300] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 20% 15%  5%  6%  6%  5%  6%  4%
# [libx264 @ 0x5578d8295300] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5578d8295300] ref P L0: 61.4%  9.7% 21.3%  7.6%
# [libx264 @ 0x5578d8295300] ref B L0: 85.5% 12.5%  2.0%
# [libx264 @ 0x5578d8295300] ref B L1: 97.0%  3.0%
# [libx264 @ 0x5578d8295300] kb/s:1755.16
